# %% [markdown]
# 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.
#
# **Решение**
#
# $$M(x) = \frac{800 + 200}{2} = 500; \,\,\, D(x) = \frac{(800-200)^2}{12}=30000$$

# %% [markdown]
# 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.
#
# **Решение**
#
# Пусть $x$ - правая граница. Тогда
#
# $$D(x) = \frac{(x-0.5)^2}{12} = 0.2; \,\,\, (x - 0.5)^2 = \frac{4 \cdot 15}{25}; \,\,\, x = 0.5 + \frac{2\sqrt{15}}{5}$$

# %% [markdown]
# 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# $f(x) = \frac{1}{4\sqrt{2\pi}} \cdot e^{-\frac{(x+2)^2}{32}}$.
# Найдите:
#
# а). M(X)
#
# б). D(X)
#
# в). std(X) (среднее квадратичное отклонение)
#
# **Решение**
#
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}}; \; a = M(X), \; \sigma^2 = D(X)$$
#
# Отсюда
#
# $$M(x) = -2;  std(x) = \sigma = \sqrt{D(x)} = 4; D(x) = 16$$

# %% [markdown]
# 4. Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
#
# а). больше 182 см
#
# б). больше 190 см
#
# в). от 166 см до 190 см
#
# г). от 166 см до 182 см
#
# д). от 158 см до 190 см
#
# е). не выше 150 см или не ниже 190 см
#
# ё). не выше 150 см или не ниже 198 см
#
# ж). ниже 166 см.
#
#
# **Решение**
#
# а) $182 - 174 = 8 = 1\sigma.\; p = 0.5 - \Phi(1) \approx 0.1687$
#
# б) $190 - 174 = 16 = 2\sigma.\; p = 0.5 - \Phi(2) \approx 0.0228$
#
# в) $190 - 174 = 16 = 2\sigma; \; 166 - 174 = -8 = -1\sigma.\; p = \Phi(1) + \Phi(2) \approx 0.8185$
#
# г) $182 - 174 = 8 = 1\sigma; \; 166 - 174 = -8 = -1\sigma.\; p = \Phi(1) + \Phi(1) \approx 0.6826$
#
# д) $190 - 174 = 16 = 2\sigma; \; 158 - 174 = -16 = -2\sigma.\; p = \Phi(2) + \Phi(2) \approx 0.9544$
#
# е) $190 - 174 = 16 = 2\sigma; \; 150 - 174 = -24 = -3\sigma.\; p = 1 - \Phi(2) - \Phi(3) \approx 0.0241$
#
# ё) $198 - 174 = 24 = 3\sigma; \; 150 - 174 = -24 = -3\sigma.\; p = 1 - \Phi(3) - \Phi(3) \approx 0.0026$
#
# ж) $166 - 174 = -8 = -1\sigma.\; p = 0.5 - \Phi(1) \approx 0.1687$

# %% [markdown]
# 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?
#
# **Решение**
#
# $$\sigma = \sqrt{D(x)} = 5 \,см. $$
# $$\frac{190-178}{5} = 2.4; \; \Phi(2.4) \approx 0.4918$$
