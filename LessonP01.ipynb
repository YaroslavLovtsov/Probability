# %% [markdown]
# 1. Из колоды в 52 карты извлекаются случайным образом 4 карты. a) Найти вероятность того, что все карты – крести. б) Найти вероятность, что среди 4-х карт окажется хотя бы один туз.
#
# **Решение**
#
# а) $$ p = \frac{C^4_9}{C^4_{52}} = \frac{\frac{9!}{5! \cdot 4!}}{\frac{52!}{48! \cdot 4!}} = \frac{9!}{5!} \cdot \frac{48!}{52!} = \frac{9 \cdot 8 \cdot 7 \cdot 6}{52 \cdot 51 \cdot 50 \cdot 49} \approx 0,0004654$$
#
# б)
#
# $$p = \frac{C^1_{4} \cdot C^3_{48} + C^2_{4} \cdot C^2_{48} + C^3_{4} \cdot C^1_{48} + C^4_{4} \cdot C^0_{48}}{{C^4_{52}}} = $$
#
# \\
#
# $$ = \frac{4! \cdot 48!}{52!}(\frac{4! \cdot 48!}{1! \cdot 3! \cdot 45! \cdot 3!} + \frac{4! \cdot 48!}{2! \cdot 2! \cdot 46! \cdot 2!} + \frac{4! \cdot 48!}{3! \cdot 1! \cdot 47! \cdot 1!} + \frac{4! \cdot 48!}{4! \cdot 0! \cdot 48! \cdot 0!}) = $$
#
# \\
#
# $$ = \frac{4!\cdot 48!}{52!} \cdot \frac{48!}{3! \cdot 45!}(\frac{4!}{3!} + \frac{3\cdot4!}{4\cdot46} + \frac{4!}{46\cdot47} + \frac{6}{46\cdot47\cdot48}) = $$
#
# \\
#
# $$=\frac{4\cdot46\cdot47\cdot48}{49\cdot50\cdot51\cdot52\cdot46\cdot47\cdot48} \cdot(4\cdot46\cdot47\cdot48  + 3\cdot6\cdot47\cdot48 + 4\cdot48 + 6) = $$
#
# \\
#
# $$ = \frac{4 \cdot 455910}{49\cdot50\cdot51\cdot52}\approx 0,28067$$

# %% [markdown]
# 2. На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. Код содержит три цифры, которые нужно нажать одновременно. Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?
#
# **Решение**
#
# $$ p = \frac{1}{C_{10}^{3}} = \frac{3! \cdot 7!}{10!} = \frac{1\cdot2\cdot3}{10\cdot9\cdot8} = \frac{1}{120}$$

# %% [markdown]
# 3. В ящике имеется 15 деталей, из которых 9 окрашены. Рабочий случайным образом извлекает 3 детали. Какова вероятность того, что все извлеченные детали окрашены?
#
# **Решение**
#
# $$p = \frac{C_{9}^{3}}{C_{15}^{3}} = \frac{9!}{3!\cdot 6!} \cdot \frac{3!\cdot 12!}{15!} = \frac{9\cdot8\cdot7}{13\cdot14\cdot15} \approx 0,18462$$

# %% [markdown]
# 4. В лотерее 100 билетов. Из них 2 выигрышных. Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?
#
# **Решение**
#
# $$p = \frac{C^{2}_{2}}{C_{100}^{2}} = \frac{1 \cdot 2}{100 \cdot 99} = \frac{1}{4950} \approx 0,000202 $$

# %% [markdown]
# 5. На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом б). вторым спортсменом в). третьим спортсменом.
#
# **Решение**
#
# $$p_1 = \frac{\frac{1}{3} \cdot 0,9}{0,9 + 0,8 + 0,6} = \frac{9}{23} \approx 0,39130
# \\
# $$
#
#
# $$p_2 = \frac{\frac{1}{3} \cdot 0,8}{\frac{1}{3} \cdot 0,9 + \frac{1}{3} \cdot 0,8 + \frac{1}{3} \cdot 0,6} = \frac{8}{23} \approx 0,34783
# \\
# $$
#
# $$p_3 = \frac{\frac{1}{3} \cdot 0,6}{\frac{1}{3} \cdot 0,9 + \frac{1}{3} \cdot 0,8 + \frac{1}{3} \cdot 0,6} = \frac{6}{23} \approx 0,26087$$
